# %%
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LeakyReLU

# my package
from utils.sparrowpy.data_science import modeling
from utils.sparrowpy.data_engg import sql

# %%
df = sql.get_table_df(
    t_main='rental',
    t_joins=[
        ['customer', 'rental.customer_id = customer.customer_id'],
        ['address', 'customer.address_id = address.address_id'],
        ['city', 'address.city_id = city.city_id'],
        ['inventory', 'rental.inventory_id = inventory.inventory_id'],
        ['film', 'inventory.film_id = film.film_id'],
        ['film_category', 'film.film_id = film_category.film_id'],
    ],
    t_cols=[
        ['rental', ['staff_id']],
        ['customer', ['store_id']],
        ['city', ['city_id']],
        ['film_category', ['category_id']],
    ],
    calc_cols="""
        EXTRACT(DAY FROM (rental.rental_date)) as day,
        EXTRACT(month FROM (rental.rental_date)) as month
    """
)
df
# Out:
# postgresql+psycopg2://postgres:postgres@localhost:5432/dvd_rental
# select rental.staff_id, customer.store_id, city.city_id, film_category.category_id,
#         EXTRACT(DAY FROM (rental.rental_date)) as day,
#         EXTRACT(month FROM (rental.rental_date)) as month
#      from rental left outer join customer on rental.customer_id = customer.customer_id left outer join address on customer.address_id = address.address_id left outer join city on address.city_id = city.city_id left outer join inventory on rental.inventory_id = inventory.inventory_id left outer join film on inventory.film_id = film.film_id left outer join film_category on film.film_id = film_category.film_id
#        staff_id  store_id  city_id  category_id day month
# 0             1         1      423           12  24     5
# 1             1         1      230            3  24     5
# 2             2         2       48           11  24     5
# 3             1         2      235            3  24     5
# 4             1         1      459            5  24     5
# ...         ...       ...      ...          ...  ..   ...
# 16039         2         1      431            4  23     8
# 16040         2         2      148            9  23     8
# 16041         1         1      220            7  23     8
# 16042         2         1      278            7  23     8
# 16043         1         1      190            8  24     5
#
# [16044 rows x 6 columns]

# %%
target_class = 'category_id'
df.corr()[target_class]
# Out:
# staff_id       0.007654
# store_id      -0.007404
# city_id        0.004347
# category_id    1.000000
# day           -0.005291
# month          0.006054
# Name: category_id, dtype: float64

# %%
encoders = {}

df_encoder = sql.get_table_df(
    query = """
    select 
        category_id,
        name
    from
        category
    group by category_id
    order by category_id

    """
)
result_dict = df_encoder.set_index('name')['category_id'].to_dict()
print(result_dict)
encoders['category_id'] = result_dict

df_encoder = sql.get_table_df(
    query = """
    select 
        city_id,
        city
    from
        city
    group by city_id
    order by city

    """
)
result_dict = df_encoder.set_index('city')['city_id'].to_dict()
print(result_dict)
encoders['city_id'] = result_dict

df_encoder = sql.get_table_df(
    query = """
    select 
        staff_id,
        first_name
    from
        staff
    group by staff_id
    order by first_name

    """
)
result_dict = df_encoder.set_index('first_name')['staff_id'].to_dict()
print(result_dict)
encoders['staff_id'] = result_dict

encoders
# Out:
# postgresql+psycopg2://postgres:postgres@localhost:5432/dvd_rental
#
#     select
#         category_id,
#         name
#     from
#         category
#     group by category_id
#     order by category_id
#
#
# {'Action': 1, 'Animation': 2, 'Children': 3, 'Classics': 4, 'Comedy': 5, 'Documentary': 6, 'Drama': 7, 'Family': 8, 'Foreign': 9, 'Games': 10, 'Horror': 11, 'Music': 12, 'New': 13, 'Sci-Fi': 14, 'Sports': 15, 'Travel': 16}
# postgresql+psycopg2://postgres:postgres@localhost:5432/dvd_rental
#
#     select
#         city_id,
#         city
#     from
#         city
#     group by city_id
#     order by city
#
#
# {'A Corua (La Corua)': 1, 'Abha': 2, 'Abu Dhabi': 3, 'Acua': 4, 'Adana': 5, 'Addis Abeba': 6, 'Aden': 7, 'Adoni': 8, 'Ahmadnagar': 9, 'Akishima': 10, 'Akron': 11, 'al-Ayn': 12, 'al-Hawiya': 13, 'al-Manama': 14, 'al-Qadarif': 15, 'al-Qatif': 16, 'Alessandria': 17, 'Allappuzha (Alleppey)': 18, 'Allende': 19, 'Almirante Brown': 20, 'Alvorada': 21, 'Ambattur': 22, 'Amersfoort': 23, 'Amroha': 24, 'Angra dos Reis': 25, 'Anpolis': 26, 'Antofagasta': 27, 'Aparecida de Goinia': 28, 'Apeldoorn': 29, 'Araatuba': 30, 'Arak': 31, 'Arecibo': 32, 'Arlington': 33, 'Ashdod': 34, 'Ashgabat': 35, 'Ashqelon': 36, 'Asuncin': 37, 'Athenai': 38, 'Atinsk': 39, 'Atlixco': 40, 'Augusta-Richmond County': 41, 'Aurora': 42, 'Avellaneda': 43, 'Bag': 44, 'Baha Blanca': 45, 'Baicheng': 46, 'Baiyin': 47, 'Baku': 48, 'Balaiha': 49, 'Balikesir': 50, 'Balurghat': 51, 'Bamenda': 52, 'Bandar Seri Begawan': 53, 'Banjul': 54, 'Barcelona': 55, 'Basel': 56, 'Bat Yam': 57, 'Batman': 58, 'Batna': 59, 'Battambang': 60, 'Baybay': 61, 'Bayugan': 62, 'Bchar': 63, 'Beira': 64, 'Bellevue': 65, 'Belm': 66, 'Benguela': 67, 'Beni-Mellal': 68, 'Benin City': 69, 'Bergamo': 70, 'Berhampore (Baharampur)': 71, 'Bern': 72, 'Bhavnagar': 73, 'Bhilwara': 74, 'Bhimavaram': 75, 'Bhopal': 76, 'Bhusawal': 77, 'Bijapur': 78, 'Bilbays': 79, 'Binzhou': 80, 'Birgunj': 81, 'Bislig': 82, 'Blumenau': 83, 'Boa Vista': 84, 'Boksburg': 85, 'Botosani': 86, 'Botshabelo': 87, 'Bradford': 88, 'Braslia': 89, 'Bratislava': 90, 'Brescia': 91, 'Brest': 92, 'Brindisi': 93, 'Brockton': 94, 'Bucuresti': 95, 'Buenaventura': 96, 'Bydgoszcz': 97, 'Cabuyao': 98, 'Callao': 99, 'Cam Ranh': 100, 'Cape Coral': 101, 'Caracas': 102, 'Carmen': 103, 'Cavite': 104, 'Cayenne': 105, 'Celaya': 106, 'Chandrapur': 107, 'Changhwa': 108, 'Changzhou': 109, 'Chapra': 110, 'Charlotte Amalie': 111, 'Chatsworth': 112, 'Cheju': 113, 'Chiayi': 114, 'Chisinau': 115, 'Chungho': 116, 'Cianjur': 117, 'Ciomas': 118, 'Ciparay': 119, 'Citrus Heights': 120, 'Citt del Vaticano': 121, 'Ciudad del Este': 122, 'Clarksville': 123, 'Coacalco de Berriozbal': 124, 'Coatzacoalcos': 125, 'Compton': 126, 'Coquimbo': 127, 'Crdoba': 128, 'Cuauhtmoc': 129, 'Cuautla': 130, 'Cuernavaca': 131, 'Cuman': 132, 'Czestochowa': 133, 'Dadu': 134, 'Dallas': 135, 'Datong': 136, 'Daugavpils': 137, 'Davao': 138, 'Daxian': 139, 'Dayton': 140, 'Deba Habe': 141, 'Denizli': 142, 'Dhaka': 143, 'Dhule (Dhulia)': 144, 'Dongying': 145, 'Donostia-San Sebastin': 146, 'Dos Quebradas': 147, 'Duisburg': 148, 'Dundee': 149, 'Dzerzinsk': 150, 'Ede': 151, 'Effon-Alaiye': 152, 'El Alto': 153, 'El Fuerte': 154, 'El Monte': 155, 'Elista': 156, 'Emeishan': 157, 'Emmen': 158, 'Enshi': 159, 'Erlangen': 160, 'Escobar': 161, 'Esfahan': 162, 'Eskisehir': 163, 'Etawah': 164, 'Ezeiza': 165, 'Ezhou': 166, 'Faaa': 167, 'Fengshan': 168, 'Firozabad': 169, 'Florencia': 170, 'Fontana': 171, 'Fukuyama': 172, 'Funafuti': 173, 'Fuyu': 174, 'Fuzhou': 175, 'Gandhinagar': 176, 'Garden Grove': 177, 'Garland': 178, 'Gatineau': 179, 'Gaziantep': 180, 'Gijn': 181, 'Gingoog': 182, 'Goinia': 183, 'Gorontalo': 184, 'Grand Prairie': 185, 'Graz': 186, 'Greensboro': 187, 'Guadalajara': 188, 'Guaruj': 189, 'guas Lindas de Gois': 190, 'Gulbarga': 191, 'Hagonoy': 192, 'Haining': 193, 'Haiphong': 194, 'Haldia': 195, 'Halifax': 196, 'Halisahar': 197, 'Halle/Saale': 198, 'Hami': 199, 'Hamilton': 200, 'Hanoi': 201, 'Hidalgo': 202, 'Higashiosaka': 203, 'Hino': 204, 'Hiroshima': 205, 'Hodeida': 206, 'Hohhot': 207, 'Hoshiarpur': 208, 'Hsichuh': 209, 'Huaian': 210, 'Hubli-Dharwad': 211, 'Huejutla de Reyes': 212, 'Huixquilucan': 213, 'Hunuco': 214, 'Ibirit': 215, 'Idfu': 216, 'Ife': 217, 'Ikerre': 218, 'Iligan': 219, 'Ilorin': 220, 'Imus': 221, 'Inegl': 222, 'Ipoh': 223, 'Isesaki': 224, 'Ivanovo': 225, 'Iwaki': 226, 'Iwakuni': 227, 'Iwatsuki': 228, 'Izumisano': 229, 'Jaffna': 230, 'Jaipur': 231, 'Jakarta': 232, 'Jalib al-Shuyukh': 233, 'Jamalpur': 234, 'Jaroslavl': 235, 'Jastrzebie-Zdrj': 236, 'Jedda': 237, 'Jelets': 238, 'Jhansi': 2 ...
# postgresql+psycopg2://postgres:postgres@localhost:5432/dvd_rental
#
#     select
#         staff_id,
#         first_name
#     from
#         staff
#     group by staff_id
#     order by first_name
#
#
# {'Jon': 2, 'Mike': 1}
# {'category_id': {'Action': 1,
#   'Animation': 2,
#   'Children': 3,
#   'Classics': 4,
#   'Comedy': 5,
#   'Documentary': 6,
#   'Drama': 7,
#   'Family': 8,
#   'Foreign': 9,
#   'Games': 10,
#   'Horror': 11,
#   'Music': 12,
#   'New': 13,
#   'Sci-Fi': 14,
#   'Sports': 15,
#   'Travel': 16},
#  'city_id': {'A Corua (La Corua)': 1,
#   'Abha': 2,
#   'Abu Dhabi': 3,
#   'Acua': 4,
#   'Adana': 5,
#   'Addis Abeba': 6,
#   'Aden': 7,
#   'Adoni': 8,
#   'Ahmadnagar': 9,
#   'Akishima': 10,
#   'Akron': 11,
#   'al-Ayn': 12,
#   'al-Hawiya': 13,
#   'al-Manama': 14,
#   'al-Qadarif': 15,
#   'al-Qatif': 16,
#   'Alessandria': 17,
#   'Allappuzha (Alleppey)': 18,
#   'Allende': 19,
#   'Almirante Brown': 20,
#   'Alvorada': 21,
#   'Ambattur': 22,
#   'Amersfoort': 23,
#   'Amroha': 24,
#   'Angra dos Reis': 25,
#   'Anpolis': 26,
#   'Antofagasta': 27,
#   'Aparecida de Goinia': 28,
#   'Apeldoorn': 29,
#   'Araatuba': 30,
#   'Arak': 31,
#   'Arecibo': 32,
#   'Arlington': 33,
#   'Ashdod': 34,
#   'Ashgabat': 35,
#   'Ashqelon': 36,
#   'Asuncin': 37,
#   'Athenai': 38,
#   'Atinsk': 39,
#   'Atlixco': 40,
#   'Augusta-Richmond County': 41,
#   'Aurora': 42,
#   'Avellaneda': 43,
#   'Bag': 44,
#   'Baha Blanca': 45,
#   'Baicheng': 46,
#   'Baiyin': 47,
#   'Baku': 48,
#   'Balaiha': 49,
#   'Balikesir': 50,
#   'Balurghat': 51,
#   'Bamenda': 52,
#   'Bandar Seri Begawan': 53,
#   'Banjul': 54,
#   'Barcelona': 55,
#   'Basel': 56,
#   'Bat Yam': 57,
#   'Batman': 58,
#   'Batna': 59,
#   'Battambang': 60,
#   'Baybay': 61,
#   'Bayugan': 62,
#   'Bchar': 63,
#   'Beira': 64,
#   'Bellevue': 65,
#   'Belm': 66,
#   'Benguela': 67,
#   'Beni-Mellal': 68,
#   'Benin City': 69,
#   'Bergamo': 70,
#   'Berhampore (Baharampur)': 71,
#   'Bern': 72,
#   'Bhavnagar': 73,
#   'Bhilwara': 74,
#   'Bhimavaram': 75,
#   'Bhopal': 76,
#   'Bhusawal': 77,
#   'Bijapur': 78,
#   'Bilbays': 79,
#   'Binzhou': 80,
#   'Birgunj': 81,
#   'Bislig': 82,
#   'Blumenau': 83,
#   'Boa Vista': 84,
#   'Boksburg': 85,
#   'Botosani': 86,
#   'Botshabelo': 87,
#   'Bradford': 88,
#   'Braslia': 89,
#   'Bratislava': 90,
#   'Brescia': 91,
#   'Brest': 92,
#   'Brindisi': 93,
#   'Brockton': 94,
#   'Bucuresti': 95,
#   'Buenaventura': 96,
#   'Bydgoszcz': 97,
#   'Cabuyao': 98,
#   'Callao': 99,
#   'Cam Ranh': 100,
#   'Cape Coral': 101,
#   'Caracas': 102,
#   'Carmen': 103,
#   'Cavite': 104,
#   'Cayenne': 105,
#   'Celaya': 106,
#   'Chandrapur': 107,
#   'Changhwa': 108,
#   'Changzhou': 109,
#   'Chapra': 110,
#   'Charlotte Amalie': 111,
#   'Chatsworth': 112,
#   'Cheju': 113,
#   'Chiayi': 114,
#   'Chisinau': 115,
#   'Chungho': 116,
#   'Cianjur': 117,
#   'Ciomas': 118,
#   'Ciparay': 119,
#   'Citrus Heights': 120,
#   'Citt del Vaticano': 121,
#   'Ciudad del Este': 122,
#   'Clarksville': 123,
#   'Coacalco de Berriozbal': 124,
#   'Coatzacoalcos': 125,
#   'Compton': 126,
#   'Coquimbo': 127,
#   'Crdoba': 128,
#   'Cuauhtmoc': 129,
#   'Cuautla': 130,
#   'Cuernavaca': 131,
#   'Cuman': 132,
#   'Czestochowa': 133,
#   'Dadu': 134,
#   'Dallas': 135,
#   'Datong': 136,
#   'Daugavpils': 137,
#   'Davao': 138,
#   'Daxian': 139,
#   'Dayton': 140,
#   'Deba Habe': 141,
#   'Denizli': 142,
#   'Dhaka': 143,
#   'Dhule (Dhulia)': 144,
#   'Dongying': 145,
#   'Donostia-San Sebastin': 146,
#   'Dos Quebradas': 147,
#   'Duisburg': 148,
#   'Dundee': 149,
#   'Dzerzinsk': 150,
#   'Ede': 151,
#   'Effon-Alaiye': 152,
#   'El Alto': 153,
#   'El Fuerte': 154,
#   'El Monte': 155,
#   'Elista': 156,
#   'Emeishan': 157,
#   'Emmen': 158,
#   'Enshi': 159,
#   'Erlangen': 160,
#   'Escobar': 161,
#   'Esfahan': 162,
#   'Eskisehir': 163,
#   'Etawah': 164,
#   'Ezeiza': 165,
#   'Ezhou': 166,
#   'Faaa': 167,
#   'Fengshan': 168,
#   'Firozabad': 169,
#   'Florencia': 170,
#   'Fontana': 171,
#   'Fukuyama': 172,
#   'Funafuti': 173,
#   'Fuyu': 174,
#   'Fuzhou': 175,
#   'Gandhinagar': 176,
#   'Garden Grove': 177,
#   'Garland': 178,
#   'Gatineau': 179,
#   'Gaziantep': 180,
#   'Gijn': 181,
#   'Gingoog': 182,
#   'Goinia': 183,
#   'Gorontalo': 184,
#   'Grand Prairie': 185,
#   'Graz': 186,
#   'Greensboro': 187,
#   'Guadalajara': 188,
#   'Guaruj': 189,
#   'guas Lindas de Gois': 190,
#   'Gulbarga': 191,
#   'Hagonoy': 192,
#   'Haining': 193,
#   'Haiphong': 194,
#   'Haldia': 195,
#   'Halifax': 196,
#   'Halisahar': 197,
#   'Halle/Saale': 198,
#   'Hami': 199,
#   'Hamilton': 200,
#   'Hanoi': 201,
#   'Hidalgo': 202,
#   'Higashiosaka': 203,
#   'Hino': 204,
#   'Hiroshima': 205,
#   'Hodeida': 206,
#   'Hohhot': 207,
#   'Hoshiarpur': 208,
#   'Hsichuh': 209,
#   'Huaian': 210,
#   'Hubli-Dharwad': 211,
#   'Huejutla de Reyes': 212,
#   'Huixquilucan': 213,
#   'Hunuco': 214,
#   'Ibirit': 215,
#   'Idfu': 216,
#   'Ife': 217,
#   'Ikerre': 218,
#   'Iligan': 219,
#   'Ilorin': 220,
#   'Imus': 221,
#   'Inegl': 222,
#   'Ipoh': 223,
#   'Isesaki': 224,
#   'Ivanovo': 225,
#   'Iwaki': 226,
#   'Iwakuni': 227,
#   'Iwatsuki': 228,
#   'Izumisano': 229,
#   'Jaffna': 230,
#   'Jaipur': 231,
#   'Jakarta': 232,
#   'Jalib al-Shuyukh': 233,
#   'Jamalpur': 234,
#   'Jaroslavl': 235,
#   'Jastrzebie-Zdrj': 236,
#   'Jedda': 237,
#   'Jelets': 238,
#   'Jhansi': 239,
#   'Jinchang': 240,
#   'Jining': 241,
#   'Jinzhou': 242,
#   'Jodhpur': 243,
#   'Johannesburg': 244,
#   'Joliet': 245,
#   'Jos Azueta': 246,
#   'Juazeiro do Norte': 247,
#   'Juiz de Fora': 248,
#   'Junan': 249,
#   'Jurez': 250,
#   'Kabul': 251,
#   'Kaduna': 252,
#   'Kakamigahara': 253,
#   'Kaliningrad': 254,
#   'Kalisz': 255,
#   'Kamakura': 256,
#   'Kamarhati': 257,
#   'Kamjanets-Podilskyi': 258,
#   'Kamyin': 259,
#   'Kanazawa': 260,
#   'Kanchrapara': 261,
#   'Kansas City': 262,
#   'Karnal': 263,
#   'Katihar': 264,
#   'Kermanshah': 265,
#   'Kilis': 266,
#   'Kimberley': 267,
#   'Kimchon': 268,
#   'Kingstown': 269,
#   'Kirovo-Tepetsk': 270,
#   'Kisumu': 271,
#   'Kitwe': 272,
#   'Klerksdorp': 273,
#   'Kolpino': 274,
#   'Konotop': 275,
#   'Koriyama': 276,
#   'Korla': 277,
#   'Korolev': 278,
#   'Kowloon and New Kowloon': 279,
#   'Kragujevac': 280,
#   'Ktahya': 281,
#   'Kuching': 282,
#   'Kumbakonam': 283,
#   'Kurashiki': 284,
#   'Kurgan': 285,
#   'Kursk': 286,
#   'Kuwana': 287,
#   'La Paz': 288,
#   'La Plata': 289,
#   'La Romana': 290,
#   'Laiwu': 291,
#   'Lancaster': 292,
#   'Laohekou': 293,
#   'Lapu-Lapu': 294,
#   'Laredo': 295,
#   'Lausanne': 296,
#   'Le Mans': 297,
#   'Lengshuijiang': 298,
#   'Leshan': 299,
#   'Lethbridge': 300,
#   'Lhokseumawe': 301,
#   'Liaocheng': 302,
#   'Liepaja': 303,
#   'Lilongwe': 304,
#   'Lima': 305,
#   'Lincoln': 306,
#   'Linz': 307,
#   'Lipetsk': 308,
#   'Livorno': 309,
#   'Ljubertsy': 310,
#   'Loja': 311,
#   'London': 313,
#   'Lublin': 314,
#   'Lubumbashi': 315,
#   'Lungtan': 316,
#   'Luzinia': 317,
#   'Madiun': 318,
#   'Mahajanga': 319,
#   'Maikop': 320,
#   'Malm': 321,
#   'Manchester': 322,
#   'Mandaluyong': 323,
#   'Mandi Bahauddin': 324,
#   'Mannheim': 325,
#   'Maracabo': 326,
#   'Mardan': 327,
#   'Maring': 328,
#   'Masqat': 329,
#   'Matamoros': 330,
#   'Matsue': 331,
#   'Meixian': 332,
#   'Memphis': 333,
#   'Merlo': 334,
#   'Mexicali': 335,
#   'Miraj': 336,
#   'Mit Ghamr': 337,
#   'Miyakonojo': 338,
#   'Mogiljov': 339,
#   'Molodetno': 340,
#   'Monclova': 341,
#   'Monywa': 342,
#   'Moscow': 343,
#   'Mosul': 344,
#   'Mukateve': 345,
#   'Munger (Monghyr)': 346,
#   'Mwanza': 347,
#   'Mwene-Ditu': 348,
#   'Myingyan': 349,
#   'Mysore': 350,
#   'Naala-Porto': 351,
#   'Nabereznyje Telny': 352,
#   'Nador': 353,
#   'Nagaon': 354,
#   'Nagareyama': 355,
#   'Najafabad': 356,
#   'Naju': 357,
#   'Nakhon Sawan': 358,
#   'Nam Dinh': 359,
#   'Namibe': 360,
#   'Nantou': 361,
#   'Nanyang': 362,
#   'NDjamna': 363,
#   'Newcastle': 364,
#   'Nezahualcyotl': 365,
#   'Nha Trang': 366,
#   'Niznekamsk': 367,
#   'Novi Sad': 368,
#   'Novoterkassk': 369,
#   'Nukualofa': 370,
#   'Nuuk': 371,
#   'Nyeri': 372,
#   'Ocumare del Tuy': 373,
#   'Ogbomosho': 374,
#   'Okara': 375,
#   'Okayama': 376,
#   'Okinawa': 377,
#   'Olomouc': 378,
#   'Omdurman': 379,
#   'Omiya': 380,
#   'Ondo': 381,
#   'Onomichi': 382,
#   'Oshawa': 383,
#   'Osmaniye': 384,
#   'ostka': 385,
#   'Otsu': 386,
#   'Oulu': 387,
#   'Ourense (Orense)': 388,
#   'Owo': 389,
#   'Oyo': 390,
#   'Ozamis': 391,
#   'Paarl': 392,
#   'Pachuca de Soto': 393,
#   'Pak Kret': 394,
#   'Palghat (Palakkad)': 395,
#   'Pangkal Pinang': 396,
#   'Papeete': 397,
#   'Parbhani': 398,
#   'Pathankot': 399,
#   'Patiala': 400,
#   'Patras': 401,
#   'Pavlodar': 402,
#   'Pemalang': 403,
#   'Peoria': 404,
#   'Pereira': 405,
#   'Phnom Penh': 406,
#   'Pingxiang': 407,
#   'Pjatigorsk': 408,
#   'Plock': 409,
#   'Po': 410,
#   'Ponce': 411,
#   'Pontianak': 412,
#   'Poos de Caldas': 413,
#   'Portoviejo': 414,
#   'Probolinggo': 415,
#   'Pudukkottai': 416,
#   'Pune': 417,
#   'Purnea (Purnia)': 418,
#   'Purwakarta': 419,
#   'Pyongyang': 420,
#   'Qalyub': 421,
#   'Qinhuangdao': 422,
#   'Qomsheh': 423,
#   'Quilmes': 424,
#   'Rae Bareli': 425,
#   'Rajkot': 426,
#   'Rampur': 427,
#   'Rancagua': 428,
#   'Ranchi': 429,
#   'Richmond Hill': 430,
#   'Rio Claro': 431,
#   'Rizhao': 432,
#   'Roanoke': 433,
#   'Robamba': 434,
#   'Rockford': 435,
#   'Ruse': 436,
#   'Rustenburg': 437,
#   's-Hertogenbosch': 438,
#   'Saarbrcken': 439,
#   'Sagamihara': 440,
#   'Saint-Denis': 442,
#   'Saint Louis': 441,
#   'Sal': 443,
#   'Salala': 444,
#   'Salamanca': 445,
#   'Salinas': 446,
#   'Salzburg': 447,
#   'Sambhal': 448,
#   'San Bernardino': 449,
#   'San Felipe de Puerto Plata': 450,
#   'San Felipe del Progreso': 451,
#   'San Juan Bautista Tuxtepec': 452,
#   'San Lorenzo': 453,
#   'San Miguel de Tucumn': 454,
#   'Sanaa': 455,
#   'Santa Brbara dOeste': 456,
#   'Santa F': 457,
#   'Santa Rosa': 458,
#   'Santiago de Compostela': 459,
#   'Santiago de los Caballeros': 460,
#   'Santo Andr': 461,
#   'Sanya': 462,
#   'Sasebo': 463,
#   'Satna': 464,
#   'Sawhaj': 465,
#   'Serpuhov': 466,
#   'Shahr-e Kord': 467,
#   'Shanwei': 468,
#   'Shaoguan': 469,
#   'Sharja': 470,
#   'Shenzhen': 471,
#   'Shikarpur': 472,
#   'Shimoga': 473,
#   'Shimonoseki': 474,
#   'Shivapuri': 475,
#   'Shubra al-Khayma': 476,
#   'Siegen': 477,
#   'Siliguri (Shiliguri)': 478,
#   'Simferopol': 479,
#   'Sincelejo': 480,
#   'Sirjan': 481,
#   'Sivas': 482,
#   'Skikda': 483,
#   'Smolensk': 484,
#   'So Bernardo do Campo': 485,
#   'So Leopoldo': 486,
#   'Sogamoso': 487,
#   'Sokoto': 488,
#   'Songkhla': 489,
#   'Sorocaba': 490,
#   'Soshanguve': 491,
#   'Sousse': 492,
#   'South Hill': 493,
#   'Southampton': 494,
#   'Southend-on-Sea': 495,
#   'Southport': 496,
#   'Springs': 497,
#   'Stara Zagora': 498,
#   'Sterling Heights': 499,
#   'Stockport': 500,
#   'Sucre': 501,
#   'Suihua': 502,
#   'Sullana': 503,
#   'Sultanbeyli': 504,
#   'Sumqayit': 505,
#   'Sumy': 506,
#   'Sungai Petani': 507,
#   'Sunnyvale': 508,
#   'Surakarta': 509,
#   'Syktyvkar': 510,
#   'Syrakusa': 511,
#   'Szkesfehrvr': 512,
#   'Tabora': 513,
#   'Tabriz': 514,
#   'Tabuk': 515,
#   'Tafuna': 516,
#   'Taguig': 517,
#   'Taizz': 518,
#   'Talavera': 519,
#   'Tallahassee': 520,
#   'Tama': 521,
#   'Tambaram': 522,
#   'Tanauan': 523,
#   'Tandil': 524,
#   'Tangail': 525,
#   'Tanshui': 526,
#   'Tanza': 527,
#   'Tarlac': 528,
#   'Tarsus': 529,
#   'Tartu': 530,
#   'Teboksary': 531,
#   'Tegal': 532,
#   'Tel Aviv-Jaffa': 533,
#   'Tete': 534,
#   'Tianjin': 535,
#   'Tiefa': 536,
#   'Tieli': 537,
#   'Tokat': 538,
#   'Tonghae': 539,
#   'Tongliao': 540,
#   'Torren': 541,
#   'Touliu': 542,
#   'Toulon': 543,
#   'Toulouse': 544,
#   'Trshavn': 545,
#   'Tsaotun': 546,
#   'Tsuyama': 547,
#   'Tuguegarao': 548,
#   'Tychy': 549,
#   'Udaipur': 550,
#   'Udine': 551,
#   'Ueda': 552,
#   'Uijongbu': 553,
#   'Uluberia': 554,
#   'Urawa': 555,
#   'Uruapan': 556,
#   'Usak': 557,
#   'Usolje-Sibirskoje': 558,
#   'Uttarpara-Kotrung': 559,
#   'Vaduz': 560,
#   'Valencia': 561,
#   'Valle de la Pascua': 562,
#   'Valle de Santiago': 563,
#   'Valparai': 564,
#   'Vancouver': 565,
#   'Varanasi (Benares)': 566,
#   'Vicente Lpez': 567,
#   'Vijayawada': 568,
#   'Vila Velha': 569,
#   'Vilnius': 570,
#   'Vinh': 571,
#   'Vitria de Santo Anto': 572,
#   'Warren': 573,
#   'Weifang': 574,
#   'Witten': 575,
#   'Woodridge': 576,
#   'Wroclaw': 577,
#   'Xiangfan': 578,
#   'Xiangtan': 579,
#   'Xintai': 580,
#   'Xinxiang': 581,
#   'Yamuna Nagar': 582,
#   'Yangor': 583,
#   'Yantai': 584,
#   'Yaound': 585,
#   'Yerevan': 586,
#   'Yinchuan': 587,
#   'Yingkou': 588,
#   'York': 589,
#   'Yuncheng': 590,
#   'Yuzhou': 591,
#   'Zalantun': 592,
#   'Zanzibar': 593,
#   'Zaoyang': 594,
#   'Zapopan': 595,
#   'Zaria': 596,
#   'Zeleznogorsk': 597,
#   'Zhezqazghan': 598,
#   'Zhoushan': 599,
#   'Ziguinchor': 600},
#  'staff_id': {'Jon': 2, 'Mike': 1}}

# %%
# target_class = 'category_id'
# correlations = df_num.corr()[target_class]
# threshold_correlation = 0.1
# features_classification = correlations[correlations.abs() > threshold_correlation].index.tolist()
# if len(features_classification) == 0:
#     print(f"Warning: No features have a correlation with '{target_class}' above the threshold of {threshold_correlation}")

# features_classification

# %%
target = 'category_id'
X = df.drop(target, axis=1)
y = df[target]

# Train-test split
X = np.array(X, dtype=float) 
y = np.array(y, dtype=float)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=69, stratify=y)

# %%
# import tensorflow as tf
# from sklearn.metrics import f1_score

# def f1(y_true, y_pred):
#     # Convert predictions to binary values
#     y_pred = tf.round(y_pred)  # Assuming binary classification
#     tp = tf.reduce_sum(tf.cast(y_true * y_pred, tf.float32))  # True Positives
#     tn = tf.reduce_sum(tf.cast((1 - y_true) * (1 - y_pred), tf.float32))  # True Negatives
#     fp = tf.reduce_sum(tf.cast((1 - y_true) * y_pred, tf.float32))  # False Positives
#     fn = tf.reduce_sum(tf.cast(y_true * (1 - y_pred), tf.float32))  # False Negatives
    
#     precision = tp / (tp + fp + tf.keras.backend.epsilon())
#     recall = tp / (tp + fn + tf.keras.backend.epsilon())
    
#     return 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())

# %%
# Feature scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
category_dict = encoders[target]
num_classes = len(np.unique(y_test))
y_train_shifted = y_train - 1  # Adjust category IDs to start from 0
y_test_shifted = y_test - 1

y_train_one_hot = to_categorical(y_train_shifted, num_classes=num_classes)
y_test_one_hot = to_categorical(y_test_shifted, num_classes=num_classes)

# Build the ANN model
model = Sequential()
model.add(Dense(1024, input_dim=X_train.shape[1]))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.3)) 
model.add(Dense(512))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.3)) 
model.add(Dense(256))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.3)) 
model.add(Dense(128))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.3)) 
model.add(Dense(64))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.3)) 
model.add(Dense(32))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.3)) 
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train_one_hot, epochs=50, batch_size=32, validation_split=0.1)

# Evaluate the model on test data
test_loss, test_accuracy = model.evaluate(X_test, y_test_one_hot)
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# c:\Users\Sparrow\.conda\envs\py12\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Sparrow\.conda\envs\py12\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.0637 - loss: 2.7784 - val_accuracy: 0.0763 - val_loss: 2.7689
# Epoch 2/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.0722 - loss: 2.7706 - val_accuracy: 0.0740 - val_loss: 2.7676
# Epoch 3/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0753 - loss: 2.7681 - val_accuracy: 0.0709 - val_loss: 2.7666
# Epoch 4/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0728 - loss: 2.7655 - val_accuracy: 0.0709 - val_loss: 2.7667
# Epoch 5/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0758 - loss: 2.7675 - val_accuracy: 0.0771 - val_loss: 2.7668
# Epoch 6/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0723 - loss: 2.7663 - val_accuracy: 0.0771 - val_loss: 2.7668
# Epoch 7/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0715 - loss: 2.7677 - val_accuracy: 0.0678 - val_loss: 2.7675
# Epoch 8/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0655 - loss: 2.7670 - val_accuracy: 0.0724 - val_loss: 2.7669
# Epoch 9/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0656 - loss: 2.7691 - val_accuracy: 0.0748 - val_loss: 2.7669
# Epoch 10/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0723 - loss: 2.7656 - val_accuracy: 0.0787 - val_loss: 2.7672
# Epoch 11/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0711 - loss: 2.7667 - val_accuracy: 0.0685 - val_loss: 2.7671
# Epoch 12/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0735 - loss: 2.7638 - val_accuracy: 0.0748 - val_loss: 2.7670
# Epoch 13/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0692 - loss: 2.7679 - val_accuracy: 0.0654 - val_loss: 2.7667
# Epoch 14/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0738 - loss: 2.7670 - val_accuracy: 0.0654 - val_loss: 2.7674
# Epoch 15/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0749 - loss: 2.7666 - val_accuracy: 0.0685 - val_loss: 2.7671
# Epoch 16/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0732 - loss: 2.7660 - val_accuracy: 0.0717 - val_loss: 2.7684
# Epoch 17/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0730 - loss: 2.7659 - val_accuracy: 0.0794 - val_loss: 2.7669
# Epoch 18/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0696 - loss: 2.7668 - val_accuracy: 0.0748 - val_loss: 2.7693
# Epoch 19/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0679 - loss: 2.7704 - val_accuracy: 0.0701 - val_loss: 2.7671
# Epoch 20/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0718 - loss: 2.7677 - val_accuracy: 0.0717 - val_loss: 2.7669
# Epoch 21/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0714 - loss: 2.7667 - val_accuracy: 0.0685 - val_loss: 2.7669
# Epoch 22/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0750 - loss: 2.7669 - val_accuracy: 0.0701 - val_loss: 2.7671
# Epoch 23/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0674 - loss: 2.7683 - val_accuracy: 0.0678 - val_loss: 2.7662
# Epoch 24/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0693 - loss: 2.7678 - val_accuracy: 0.0717 - val_loss: 2.7669
# Epoch 25/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0717 - loss: 2.7682 - val_accuracy: 0.0755 - val_loss: 2.7668
# Epoch 26/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0740 - loss: 2.7652 - val_accuracy: 0.0646 - val_loss: 2.7668
# Epoch 27/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0693 - loss: 2.7679 - val_accuracy: 0.0701 - val_loss: 2.7667
# Epoch 28/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0673 - loss: 2.7678 - val_accuracy: 0.0717 - val_loss: 2.7669
# Epoch 29/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0636 - loss: 2.7680 - val_accuracy: 0.0654 - val_loss: 2.7681
# Epoch 30/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0762 - loss: 2.7675 - val_accuracy: 0.0678 - val_loss: 2.7672
# Epoch 31/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0676 - loss: 2.7679 - val_accuracy: 0.0748 - val_loss: 2.7670
# Epoch 32/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0696 - loss: 2.7666 - val_accuracy: 0.0693 - val_loss: 2.7671
# Epoch 33/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0750 - loss: 2.7673 - val_accuracy: 0.0678 - val_loss: 2.7685
# Epoch 34/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0728 - loss: 2.7659 - val_accuracy: 0.0748 - val_loss: 2.7681
# Epoch 35/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0720 - loss: 2.7661 - val_accuracy: 0.0717 - val_loss: 2.7676
# Epoch 36/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0746 - loss: 2.7667 - val_accuracy: 0.0771 - val_loss: 2.7670
# Epoch 37/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0741 - loss: 2.7667 - val_accuracy: 0.0771 - val_loss: 2.7671
# Epoch 38/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0727 - loss: 2.7652 - val_accuracy: 0.0693 - val_loss: 2.7669
# Epoch 39/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0711 - loss: 2.7681 - val_accuracy: 0.0670 - val_loss: 2.7672
# Epoch 40/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0710 - loss: 2.7659 - val_accuracy: 0.0732 - val_loss: 2.7676
# Epoch 41/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0728 - loss: 2.7676 - val_accuracy: 0.0763 - val_loss: 2.7671
# Epoch 42/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0766 - loss: 2.7658 - val_accuracy: 0.0693 - val_loss: 2.7678
# Epoch 43/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0740 - loss: 2.7666 - val_accuracy: 0.0693 - val_loss: 2.7669
# Epoch 44/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0702 - loss: 2.7690 - val_accuracy: 0.0771 - val_loss: 2.7668
# Epoch 45/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0726 - loss: 2.7660 - val_accuracy: 0.0709 - val_loss: 2.7671
# Epoch 46/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0710 - loss: 2.7653 - val_accuracy: 0.0763 - val_loss: 2.7672
# Epoch 47/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0696 - loss: 2.7682 - val_accuracy: 0.0678 - val_loss: 2.7675
# Epoch 48/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0722 - loss: 2.7675 - val_accuracy: 0.0685 - val_loss: 2.7677
# Epoch 49/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0713 - loss: 2.7676 - val_accuracy: 0.0709 - val_loss: 2.7677
# Epoch 50/50
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0731 - loss: 2.7666 - val_accuracy: 0.0771 - val_loss: 2.7671
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0770 - loss: 2.7660
# Test Accuracy: 0.0742

# %%
print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 512)            │         3,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 16)             │           528 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 534,482 (2.04 MB)
#  Trainable params: 178,160 (695.94 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 356,322 (1.36 MB)
# None

# %%
def result(prediction, encoder=None):
    if encoder: category_dict = {v: k for k, v in encoder.items()}



    predicted_category_id = np.argmax(prediction) + 1
    predicted_category_name = category_dict.get(predicted_category_id, "Unknown Category")
    return f"""
        Prediction: {prediction} \n
        Prediction argmax: {np.argmax(prediction)} \n
        Predicted Genre ID: {predicted_category_id} \n
        Predicted Genre Name: {predicted_category_name} \n
    """

# %%
modeling.save_model(
    reset=False,
    model_name = 'genre',
    target = target,
    model = model,
    model_format='keras',
    scaler = scaler,
    features = list(df.drop(target, axis=1).columns),
    result = result,
    encoders = encoders
)
