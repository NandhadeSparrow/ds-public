# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
df = pd.read_csv("dataset/dvd_rental_joined_data.csv")

# Data Overview
print("datatype:", df.info())
print("\nShape:", df.shape)
print("\nUnique values per column:", df.nunique())
print("\nMissing values:", df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160230 entries, 0 to 160229
# Data columns (total 27 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   film_title        160230 non-null  object
#  1   film_description  160230 non-null  object
#  2   release_year      160230 non-null  int64
#  3   rental_duration   160230 non-null  int64
#  4   rental_rate       160230 non-null  float64
#  5   length            160230 non-null  int64
#  6   replacement_cost  160230 non-null  float64
#  7   rating            160230 non-null  object
#  8   special_features  160230 non-null  object
#  9   film_language     160230 non-null  object
#  10  film_genre        160230 non-null  object
#  11  rental_date       160230 non-null  object
#  12  return_date       158212 non-null  object
#  13  payment_amount    160230 non-null  float64
#  14  payment_date      160230 non-null  object
#  15  actor_name        160230 non-null  object
#  16  customer_name     160230 non-null  object
#  17  email_id          160230 non-null  object
#  18  membership        160230 non-null  bool
#  19  address           160230 non-null  object
#  20  phone_number      160230 non-null  int64
#  21  district          159182 non-null  object
#  22  city              160230 non-null  object
#  23  country           160230 non-null  object
#  24  staff_name        160230 non-null  object
#  25  availability      160230 non-null  bool
#  26  store_id          160230 non-null  int64
# dtypes: bool(2), float64(3), int64(5), object(17)
# memory usage: 30.9+ MB
# datatype: None
#
# Shape: (160230, 27)
#
# Unique values per column: film_title            955
# film_description      955
# release_year            1
# rental_duration         5
# rental_rate             3
# length                140
# replacement_cost       21
# rating                  5
# special_features       15
# film_language           1
# film_genre             16
# rental_date         14327
# return_date         14350
# payment_amount         19
# payment_date        14328
# actor_name            199
# customer_name         599
# email_id              599
# membership              2
# address               599
# phone_number          599
# district              375
# city                  597
# country               108
# staff_name              2
# availability            1
# store_id                2
# dtype: int64
#
# Missing values: film_title             0
# film_description       0
# release_year           0
# rental_duration        0
# rental_rate            0
# length                 0
# replacement_cost       0
# rating                 0
# special_features       0
# film_language          0
# film_genre             0
# rental_date            0
# return_date         2018
# payment_amount         0
# payment_date           0
# actor_name             0
# customer_name          0
# email_id               0
# membership             0
# address                0
# phone_number           0
# district            1048
# city                   0
# country                0
# staff_name             0
# availability           0
# store_id               0
# dtype: int64

# %%
# Drop rows with missing values
df.dropna(inplace=True)

# Check for duplicates and drop if any
print("\nDuplicate rows:", df.duplicated().sum())
df.drop_duplicates(inplace=True)

# Verify changes
print("\nShape after cleaning:", df.shape)
# Out:
# Duplicate rows: 78582
#
# Shape after cleaning: (78582, 27)

# %%
print("datatype:\n", df.info())
print("\nUnique values per column:\n", df.nunique())
print("\nMissing values:\n", df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 78582 entries, 0 to 79121
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   film_title        78582 non-null  object
#  1   film_description  78582 non-null  object
#  2   release_year      78582 non-null  int64
#  3   rental_duration   78582 non-null  int64
#  4   rental_rate       78582 non-null  float64
#  5   length            78582 non-null  int64
#  6   replacement_cost  78582 non-null  float64
#  7   rating            78582 non-null  object
#  8   special_features  78582 non-null  object
#  9   film_language     78582 non-null  object
#  10  film_genre        78582 non-null  object
#  11  rental_date       78582 non-null  object
#  12  return_date       78582 non-null  object
#  13  payment_amount    78582 non-null  float64
#  14  payment_date      78582 non-null  object
#  15  actor_name        78582 non-null  object
#  16  customer_name     78582 non-null  object
#  17  email_id          78582 non-null  object
#  18  membership        78582 non-null  bool
#  19  address           78582 non-null  object
#  20  phone_number      78582 non-null  int64
#  21  district          78582 non-null  object
#  22  city              78582 non-null  object
#  23  country           78582 non-null  object
#  24  staff_name        78582 non-null  object
#  25  availability      78582 non-null  bool
#  26  store_id          78582 non-null  int64
# dtypes: bool(2), float64(3), int64(5), object(17)
# memory usage: 15.7+ MB
# datatype:
#  None
#
# Unique values per column:
#  film_title            955
# film_description      955
# release_year            1
# rental_duration         5
# rental_rate             3
# length                140
# replacement_cost       21
# rating                  5
# special_features       15
# film_language           1
# film_genre             16
# rental_date         14231
# return_date         14257
# payment_amount         12
# payment_date        14233
# actor_name            199
# customer_name         596
# email_id              596
# membership              2
# address               596
# phone_number          596
# district              375
# city                  594
# country               105
# staff_name              2
# availability            1
# store_id                2
# dtype: int64
#
# Missing values:
#  film_title          0
# film_description    0
# release_year        0
# rental_duration     0
# rental_rate         0
# length              0
# replacement_cost    0
# rating              0
# special_features    0
# film_language       0
# film_genre          0
# rental_date         0
# return_date         0
# payment_amount      0
# payment_date        0
# actor_name          0
# customer_name       0
# email_id            0
# membership          0
# address             0
# phone_number        0
# district            0
# city                0
# country             0
# staff_name          0
# availability        0
# store_id            0
# dtype: int64

# %%
df.head()
# Out:
#     film_title                                   film_description  \
# 0  Rules Human  A Beautiful Epistle of a Astronaut And a Stude...
# 1  Rules Human  A Beautiful Epistle of a Astronaut And a Stude...
# 2  Rules Human  A Beautiful Epistle of a Astronaut And a Stude...
# 3  Rules Human  A Beautiful Epistle of a Astronaut And a Stude...
# 4  Rules Human  A Beautiful Epistle of a Astronaut And a Stude...
#
#    release_year  rental_duration  rental_rate  length  replacement_cost  \
# 0          2006                6         4.99     153             19.99
# 1          2006                6         4.99     153             19.99
# 2          2006                6         4.99     153             19.99
# 3          2006                6         4.99     153             19.99
# 4          2006                6         4.99     153             19.99
#
#   rating                        special_features film_language  ...  \
# 0      R  {"Deleted Scenes","Behind the Scenes"}       English  ...
# 1      R  {"Deleted Scenes","Behind the Scenes"}       English  ...
# 2      R  {"Deleted Scenes","Behind the Scenes"}       English  ...
# 3      R  {"Deleted Scenes","Behind the Scenes"}       English  ...
# 4      R  {"Deleted Scenes","Behind the Scenes"}       English  ...
#
#                           email_id membership              address  \
# 0  peter.menard@sakilacustomer.org       True  1217 Konotop Avenue
# 1  peter.menard@sakilacustomer.org       True  1217 Konotop Avenue
# 2  peter.menard@sakilacustomer.org       True  1217 Konotop Avenue
# 3  peter.menard@sakilacustomer.org       True  1217 Konotop Avenue
# 4  peter.menard@sakilacustomer.org       True  1217 Konotop Avenue
#
#    phone_number    district city      country    staff_name  availability  \
# 0  718917251754  Gelderland  Ede  Netherlands  Jon Stephens          True
# 1  718917251754  Gelderland  Ede  Netherlands  Jon Stephens          True
# 2  718917251754  Gelderland  Ede  Netherlands  Jon Stephens          True
# 3  718917251754  Gelderland  Ede  Netherlands  Jon Stephens          True
# 4  718917251754  Gelderland  Ede  Netherlands  Jon Stephens          True
#
#   store_id
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#
# [5 rows x 27 columns]

# %% [markdown]
# ### 1) Customer Analysis

# %%
# Top 10 customers by rental count
top_customers = df['customer_name'].value_counts().nlargest(10)

# Plot the top 10 customers by rental count
plt.figure(figsize=(10, 6))
barplot = sns.barplot(
    y=top_customers.index, 
    x=top_customers.values,
    hue=top_customers.index,
    palette='coolwarm',
    edgecolor='black'
)

# Add rental count values above the bars
for index, value in enumerate(top_customers.values):
    plt.text(value + 1.5, index, str(value), va='center', fontsize=10, fontweight='bold')

# Plot settings
plt.title('Top Customers by Rental Count', fontsize=14, fontweight='bold')
plt.xlabel('Number of Rentals')
plt.ylabel('Customer Name')
plt.show()

# Display the top customers with their rental counts
print("Top Customers with Rental Count:")
for customer, count in zip(top_customers.index, top_customers.values):
    print(f'{customer}: {count} rentals')
# Out:
# Top Customers with Rental Count:
# Eleanor Hunt: 262 rentals
# Karl Seal: 238 rentals
# Clara Shaw: 230 rentals
# Marion Snyder: 217 rentals
# Angela Hernandez: 213 rentals
# Marcia Dean: 210 rentals
# Curtis Irby: 209 rentals
# Melissa King: 208 rentals
# Marsha Douglas: 204 rentals
# Tommy Collazo: 204 rentals

# %%
# Count of Active vs Non-Active customers
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='membership', hue='membership', edgecolor='black', palette='coolwarm')

# Calculate the counts of active and non-active customers
active_count = df['membership'].value_counts().get('Active', 1)
non_active_count = df['membership'].value_counts().get('Non-Active', 0)

# Set the title to include counts
plt.title(f'Customer Active Status (Active: {active_count}, Non-Active: {non_active_count})', fontsize=14, fontweight='bold')
plt.xlabel('Membership')
plt.ylabel('Number of Customers')

# Show the counts on the bars as whole numbers
for p in plt.gca().patches:
    plt.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2, p.get_height()), 
                 ha='center', va='bottom')

plt.show()

# %%
# Film preferences of Active vs Non-Active customers
plt.figure(figsize=(10, 6))
active_genres = df[df['membership'] == True]['film_genre'].value_counts().head(10)
non_active_genres = df[df['membership'] == False]['film_genre'].value_counts().head(10)

# Plot for active customers
plt.subplot(1, 2, 1)
active_genres.plot(kind='bar', color='green', edgecolor='black')
plt.title('Top 10 Genres for Active Customers', fontsize=12, fontweight='bold')
plt.xlabel('Film Genre')
plt.ylabel('Count')
plt.xticks(rotation=45)

# Plot for non-active customers
plt.subplot(1, 2, 2)
non_active_genres.plot(kind='bar', color='red', edgecolor='black')
plt.title('Top 10 Genres for Non-Active Customers', fontsize=12, fontweight='bold')
plt.xlabel('Film Genre')
plt.ylabel('Count')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
# Ensure rental_date is in datetime format
df['rental_date'] = pd.to_datetime(df['rental_date'])

# Define a custom color palette
custom_palette = ['red', 'green']

# Plot using the custom palette
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='rental_date', hue='membership', multiple='stack', palette=custom_palette, bins=30)
plt.title('Rental Frequency of Active vs Non-Active Customers', fontsize=14, fontweight='bold')
plt.xlabel('Rental Date')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2) Film Rental Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set a color palette using Seaborn for better aesthetics
sns.set_palette('pastel')

# Top rented films
top_films = df['film_title'].value_counts().head(10)

# Create a bar chart with customizations
plt.figure(figsize=(10, 6))
top_films.plot(kind='bar', color=sns.color_palette('coolwarm', len(top_films)), edgecolor='black')  # Set bar colors using a color palette

# Add chart title and labels
plt.title('Top 10 Rented Films', fontsize=14, fontweight='bold')
plt.xlabel('Film Title', fontsize=12)
plt.ylabel('Number of Rentals', fontsize=12)

# Add a grid for better visual clarity
# plt.grid(axis='y', linestyle='--', alpha=0.7)

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Annotate bars with rental counts
for index, value in enumerate(top_films):
    plt.text(index, value, str(value), ha='center', va='bottom', fontsize=10)

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Rental Rates Distribution

plt.figure(figsize=(10, 6))
sns.histplot(df['rental_rate'], bins=30, color='skyblue', kde=True)
plt.title('Distribution of Rental Rates', fontsize=14, fontweight='bold')
plt.xlabel('Rental Rate')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Summary of rental rates with their counts
rental_rate_counts = df['rental_rate'].value_counts().sort_index()

# Print rental rates with their counts
print("Rental Rates with Counts:")
for rate, count in rental_rate_counts.items():
    print(f"Rental Rate: {rate:.2f} - Count: {count}")
# Out:
# Rental Rates with Counts:
# Rental Rate: 0.99 - Count: 27759
# Rental Rate: 2.99 - Count: 25886
# Rental Rate: 4.99 - Count: 24937

# %%
# Define film length groups
def categorize_length(length):
    if length < 60:
        return 'Short (< 60 min)'
    elif 60 <= length < 120:
        return 'Medium (60-120 min)'
    else:
        return 'Long (> 180 min)'

# Create a new column for film length groups
df['film_length_group'] = df['length'].apply(categorize_length)

# Plotting the histogram of film lengths
plt.figure(figsize=(10, 6))
plt.hist(df['length'], bins=20, color='lightgreen', edgecolor='black')
plt.title('Distribution of Film Length', fontsize=14, fontweight='bold')
plt.xlabel('Film Length (minutes)')
plt.ylabel('Frequency')
plt.show()

# Count of films in each length group
length_group_counts = df['film_length_group'].value_counts()

# Print the counts of each length group
print("Film Length Groups with Counts:")
for group, count in length_group_counts.items():
    print(f"{group}: {count}")
# Out:
# Film Length Groups with Counts:
# Long (> 180 min): 36477
# Medium (60-120 min): 34483
# Short (< 60 min): 7622

# %%
# Top Film Categories
category_counts = df['film_genre'].value_counts()

plt.figure(figsize=(10, 6))
category_counts.plot(kind='bar', color='salmon', edgecolor='black')

# Add chart title and labels
plt.title('Top Film Categories', fontsize=14, fontweight='bold')
plt.xlabel('Film Genre', fontsize=12)
plt.ylabel('Number of Films', fontsize=12)
plt.xticks(rotation=45)

# Annotate bars with film counts
for index, value in enumerate(category_counts):
    plt.text(index, value, str(value), ha='center', va='bottom', fontsize=10)

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Average rental rate by genre
avg_rental_by_genre = df.groupby('film_genre')['rental_rate'].mean().sort_values()

plt.figure(figsize=(10, 6))
avg_rental_by_genre.plot(kind='bar', color='violet', edgecolor='black')
plt.title('Average Rental Rate by Film Genre', fontsize=14, fontweight='bold')
plt.xlabel('Film Genre')
plt.ylabel('Average Rental Rate')
plt.xticks(rotation=45)
plt.show()

# Calculate average rental rate by film genre
avg_rental_by_genre = df.groupby('film_genre')['rental_rate'].mean().sort_values()

# Print the average rental rates
print("Average Rental Rate by Film Genre:", avg_rental_by_genre)
# Out:
# Average Rental Rate by Film Genre: film_genre
# Documentary    2.453773
# Action         2.537984
# Children       2.583605
# Classics       2.646434
# Family         2.668189
# Horror         2.773269
# Animation      2.817499
# Foreign        3.033435
# Sci-Fi         3.047722
# New            3.054627
# Music          3.094867
# Sports         3.147953
# Games          3.156010
# Drama          3.211583
# Comedy         3.280362
# Travel         3.396489
# Name: rental_rate, dtype: float64

# %%
# Film Rating Distribution

plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='rating', hue='rating', palette='viridis', edgecolor='black', legend=False)
plt.title('Film Rating Distribution', fontsize=14, fontweight='bold')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# Film ratings with their counts
rating_counts = df['rating'].value_counts()

# Print the ratings with counts
print("Film Ratings with Counts:")
for rating, count in rating_counts.items():
    print(f"{rating}: {count}")
# Out:
# Film Ratings with Counts:
# PG-13: 16914
# PG: 16779
# NC-17: 15768
# R: 15403
# G: 13718

# %%
# Count movies per actor
actor_counts = df.groupby('actor_name').size().reset_index(name='movie_count').sort_values(by='movie_count', ascending=False)

# Plot the top 10 actors by movie count
plt.figure(figsize=(10, 6))
barplot = sns.barplot(x='movie_count', y='actor_name', hue='actor_name', data=actor_counts.head(10), palette='viridis')

# Add movie count values above the bars
for index, value in enumerate(actor_counts.head(10)['movie_count']):
    plt.text(value + 0.5, index, str(value), va='center', fontsize=10, fontweight='bold')

# Plot settings
plt.title('Top 10 Actors by Movie Count', fontsize=14, fontweight='bold')
plt.xlabel('Number of Movies')
plt.ylabel('Actor Name')
plt.legend([], [], frameon=False)  # Remove legend
plt.show()

# Identify the top 10 actors with the maximum number of movies
top_10_actors = actor_counts.head(10)
print("Top Actors with movie count:")
for index, row in top_10_actors.iterrows():
    print(f'{row["actor_name"]} - {row["movie_count"]} movies')
# Out:
# Top Actors with movie count:
# Susan Davis - 736 movies
# Gina Degeneres - 670 movies
# Matthew Carrey - 600 movies
# Mary Keitel - 593 movies
# Walter Torn - 574 movies
# Angela Witherspoon - 572 movies
# Henry Berry - 556 movies
# Val Bolger - 552 movies
# Jayne Nolte - 551 movies
# Sandra Kilmer - 542 movies

# %% [markdown]
# ### 3) Time-series Analysis

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ensure 'rental_date' is in datetime format
df['rental_date'] = pd.to_datetime(df['rental_date'])

# Resample the data on a daily frequency
rentals_per_day = df.resample('D', on='rental_date').size()

# Plotting the number of rentals over time
plt.figure(figsize=(10, 6))
plt.plot(rentals_per_day.index, rentals_per_day.values, color='green', alpha=0.7)

# Adding title and labels
plt.title('Number of Rentals Over Time', fontsize=14, fontweight='bold')
plt.xlabel('Date')
plt.ylabel('Number of Rentals')

# Adding gridlines for better readability
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# %%
df['rental_month'] = df['rental_date'].dt.month
rentals_by_month = df['rental_month'].value_counts().sort_index()

# Print rental count by month
print("Rental Count by Month:", rentals_by_month)

# Plot the rentals per month
plt.figure(figsize=(10, 6))
sns.barplot(x=rentals_by_month.index, y=rentals_by_month.values, hue=rentals_by_month.index, palette='plasma', edgecolor='black')
plt.title('Rentals Per Month', fontsize=14, fontweight='bold')
plt.xlabel('Month')
plt.ylabel('Number of Rentals')
plt.show()
# Out:
# Rental Count by Month: rental_month
# 6    10969
# 7    36618
# 8    30995
# Name: count, dtype: int64

# %%
# Rentals by day of the week
df['rental_day_of_week'] = df['rental_date'].dt.day_name()
rentals_by_week = df['rental_day_of_week'].value_counts()

# Plot the rentals by day of the week
plt.figure(figsize=(10, 6))
barplot = sns.barplot(
    x=rentals_by_week.index, 
    y=rentals_by_week.values, 
    hue=rentals_by_week.index,
    edgecolor='black',
    palette='winter', 
    dodge=False
)

# Add rental counts above bars
for index, value in enumerate(rentals_by_week.values):
    plt.text(index, value + 0.5, str(value), ha='center', va='bottom', fontsize=10, fontweight='bold')

# Plot settings
plt.title('Rentals by Day of the Week', fontsize=14, fontweight='bold')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Rentals')
plt.xticks(rotation=45)
plt.legend([],[], frameon=False)  # Remove legend
plt.show()

# %%
# Rentals by days
df['rental_days'] = df['rental_date'].dt.day
rentals_by_days = df['rental_days'].value_counts().sort_index()

plt.figure(figsize=(10, 6))
sns.barplot(x=rentals_by_days.index, y=rentals_by_days.values, palette='plasma', edgecolor='black',)
plt.title('Rentals Per Days', fontsize=14, fontweight='bold')
plt.xlabel('Days')
plt.ylabel('Number of Rentals')
plt.show()
# Out:
# C:\Users\Sparrow\AppData\Local\Temp\ipykernel_22336\2022833048.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=rentals_by_days.index, y=rentals_by_days.values, palette='plasma', edgecolor='black',)

# %%
# Identify numerical and categorical columns
numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns.tolist()
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()

# Print numerical and categorical columns
print("Numerical Columns:")
print(numerical_cols)
print("\nCategorical Columns:")
print(categorical_cols)
# Out:
# Numerical Columns:
# ['release_year', 'rental_duration', 'rental_rate', 'length', 'replacement_cost', 'payment_amount', 'phone_number', 'store_id']
#
# Categorical Columns:
# ['film_title', 'film_description', 'rating', 'special_features', 'film_language', 'film_genre', 'return_date', 'payment_date', 'actor_name', 'customer_name', 'email_id', 'address', 'district', 'city', 'country', 'staff_name', 'film_length_group', 'rental_day_of_week']

# %%
# Identify constant columns
constant_columns = [col for col in df.columns if df[col].nunique() <= 1]
print("Constant Columns:", constant_columns)

# Drop constant columns
df.drop(columns=constant_columns, inplace=True)

# Retrieve column names
print(df.columns)

# Display the shape of the DataFrame after dropping columns
print("Shape of DataFrame after dropping constant and duplicate columns:", df.shape)
# Out:
# Constant Columns: ['release_year', 'film_language', 'availability']
# Index(['film_title', 'film_description', 'rental_duration', 'rental_rate',
#        'length', 'replacement_cost', 'rating', 'special_features',
#        'film_genre', 'rental_date', 'return_date', 'payment_amount',
#        'payment_date', 'actor_name', 'customer_name', 'email_id', 'membership',
#        'address', 'phone_number', 'district', 'city', 'country', 'staff_name',
#        'store_id', 'film_length_group', 'rental_month', 'rental_day_of_week',
#        'rental_days'],
#       dtype='object')
# Shape of DataFrame after dropping constant and duplicate columns: (78582, 28)

# %%
# Ensure only numerical columns are used for the correlation matrix
numerical_df = df.select_dtypes(include=['float64', 'int64'])

# Compute the correlation matrix for numerical columns
correlation_matrix = numerical_df.corr()

# Set up the matplotlib figure
plt.figure(figsize=(12, 8))

# Draw the heatmap with annotations and a colorbar
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5, fmt=".2f")

# Add title to the heatmap
plt.title('Correlation Heatmap for DVD Rental Dataset', fontsize=16, fontweight='bold')
plt.show()
